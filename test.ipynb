# %%
# Import the libraries and setup the OPenAI API key
import openai 
import os
import datetime

# Patheon Lore Imports
from dict_world_hist import world_hist
from dict_player_lore import race_dict, class_dict  
from dict_castigue import *
from dict_npc_char import npc_dict

import json

# Fiction and Pantheon Lore.

# Load API Key
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())
openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_quest(player_race, player_class, model="gpt-4-1106-preview", word_limit=100):
    client = openai.Client()

    # Access race and class lore from the dictionary
    race_lore = race_dict.get(player_race, "Default race lore if not found")
    class_lore = class_dict.get(player_class, "Default class lore if not found")

    # Constructing the player profile
    player_profile = f"The player is a {player_race} {player_class}, known as an adventurer or traveler."

   # Context for the NPC interaction
    context = f"""Cleo {npc_dict["cleo_feylindar"]} the adventurer stumbles upon Cleo in a secret cavern in Halnir's cave. 
    Cleo is there studing some old tomes about {castigue} and {world_hist["frail_sum"]}. 
    Cleo speaks to the adventurer in 2nd person dialog narrative. 
    She does not know their name, she addresses them by one of the follwing; class, race, a pet name, or adventurer."""

    # Cleo's dialogue
    cleo_dialogue = f""" Cleo offers a quest, in 2nd person dialog and spins tale in doing so.
    Provide strong characterization of Cleo.
    She seeks legendary cipher scrolls that are said contain the secrets to translating the language of Drak’Elri, 
    the language of dragons. Cleo use and the skills of {class_lore} to connive them to search the depths of Hainir's cave and beyond for these scrolls. 
    Cleo playfully teases the adventure in these matters. leveraging the adventures {race_lore} and {class_lore} and their place in the Frail Age, trying to coax them into this quest.
    She hints that this is a start to a very beautiful and lucrative relationship, all of her relationships are, with a wink"""

    # Combining messages with race and class lore
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": cleo_dialogue}
    ]

    # API Call v. 1.6.1
    try:
        response = client.chat.completions.create(
            model=model,
            messages=messages,
            temperature=0.7
        )
        
        # Print the response object to understand its structure
        print("Response Object:", response)

        # Adjust the following line according to the actual structure of the response
        content = response.choices[0].message.content  # Adjusted for potential object attribute access

    except Exception as e:  # Catching a more general exception for broader error handling
        print(f"Error accessing response content: {e}")
        content = "Error retrieving content."

    return content
    
def save_to_json(data, filename):
    print(f"Saving data to JSON file: {filename}")
    try:
        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to JSON: {e}")

# Lists of races and classes
races = ["gnome"]
classes = ["enchanter"]  # Add more classes as needed

# Dictionary to store all responses
quest_responses = {}

# Iterate through each combination of race and class
for race in races:
    for class_ in classes:
        response = get_quest(race, class_)
        quest_key = f"{race}_{class_}"  # Create a unique key for each combination
        quest_responses[quest_key] = response
        print(f"Race: {race}, Class: {class_}\n{response}\n")

# Generate a unique filename with timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
filename = f"quest_data_{timestamp}.json"

# Save all responses to a uniquely named JSON file
save_to_json(quest_responses, filename)
# Out:
# Response Object: ChatCompletion(id='chatcmpl-8azqF73l6Kj73dl5xzIRxQpJMYLVS', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='As the adventurer steps further into the dimly lit expanse of Halnir\'s Cave, a soft, melodic voice resonates through the cavern, drawing them forward. The source of the siren call is revealed to be none other than Cleo, the enchanting Feylindar, lounging amidst a stack of ancient tomes and scrolls.\n\n"Well, well, what brings a curious traveler like yourself to the depths of this forgotten place?" Cleo\'s tone is light, playful, yet there\'s an edge of sharpness to it, like the blade of a finely honed dagger. Her eyes, reminiscent of twilight skies, lock onto you with an intensity that belies her carefree demeanor.\n\n"Ah, a Gnomish enchanter," she purrs, a smile dancing upon her lips. "A master of the arcane, a weaver of minds. Just the sort of companion I need for a little venture of mine." Cleo rises gracefully, her movements a ballet of purpose and seduction as she circles you, appraising you with a keen eye.\n\n"You see, my inquisitive friend," she continues, "I am in pursuit of something... exceptional. Legendary cipher scrolls that are said to contain the secrets to translating the language of Drak’Elrin—the very tongue of dragons. Can you imagine the power held within those writings?"\n\nHer fingers trace the edge of a scroll, and her gaze meets yours with an intensity that borders on hypnotic. "The Enchanter, with a single word, bends wills and shapes destinies. And you, my ethereal traveler, with your mastery of order amidst chaos, are uniquely suited to aid me in this quest."\n\nLeaning in close, the scent of wildflowers and ancient parchment mingling in the air between you, she whispers, "Imagine the glory, the knowledge, the sheer thrill of unlocking such ancient, hidden truths. And let\'s not forget the rewards that come with such discoveries."\n\nWith a playful wink, she adds, "This could be the beginning of a very beautiful and lucrative relationship, don\'t you agree? All of my partnerships are, after all."\n\nCleo steps back, allowing you a moment to consider her proposal. "What say you, little enchanter? Will you join me in unraveling the mysteries that have been lost to the ages? Will you help us claim our place in this Frail Age, and perhaps... turn the tides of our shared destiny?"\n\nHer question hangs in the air, a tantalizing invitation that beckons you towards adventure, danger, and the allure of the unknown.', role='assistant', function_call=None, tool_calls=None))], created=1703828219, model='gpt-4-1106-preview', object='chat.completion', system_fingerprint='fp_3905aa4f79', usage=CompletionUsage(completion_tokens=530, prompt_tokens=2257, total_tokens=2787))
# Race: gnome, Class: enchanter
# As the adventurer steps further into the dimly lit expanse of Halnir's Cave, a soft, melodic voice resonates through the cavern, drawing them forward. The source of the siren call is revealed to be none other than Cleo, the enchanting Feylindar, lounging amidst a stack of ancient tomes and scrolls.
#
# "Well, well, what brings a curious traveler like yourself to the depths of this forgotten place?" Cleo's tone is light, playful, yet there's an edge of sharpness to it, like the blade of a finely honed dagger. Her eyes, reminiscent of twilight skies, lock onto you with an intensity that belies her carefree demeanor.
#
# "Ah, a Gnomish enchanter," she purrs, a smile dancing upon her lips. "A master of the arcane, a weaver of minds. Just the sort of companion I need for a little venture of mine." Cleo rises gracefully, her movements a ballet of purpose and seduction as she circles you, appraising you with a keen eye.
#
# "You see, my inquisitive friend," she continues, "I am in pursuit of something... exceptional. Legendary cipher scrolls that are said to contain the secrets to translating the language of Drak’Elrin—the very tongue of dragons. Can you imagine the power held within those writings?"
#
# Her fingers trace the edge of a scroll, and her gaze meets yours with an intensity that borders on hypnotic. "The Enchanter, with a single word, bends wills and shapes destinies. And you, my ethereal traveler, with your mastery of order amidst chaos, are uniquely suited to aid me in this quest."
#
# Leaning in close, the scent of wildflowers and ancient parchment mingling in the air between you, she whispers, "Imagine the glory, the knowledge, the sheer thrill of unlocking such ancient, hidden truths. And let's not forget the rewards that come with such discoveries."
#
# With a playful wink, she adds, "This could be the beginning of a very beautiful and lucrative relationship, don't you agree? All of my partnerships are, after all."
#
# Cleo steps back, allowing you a moment to consider her proposal. "What say you, little enchanter? Will you join me in unraveling the mysteries that have been lost to the ages? Will you help us claim our place in this Frail Age, and perhaps... turn the tides of our shared destiny?"
#
# Her question hangs in the air, a tantalizing invitation that beckons you towards adventure, danger, and the allure of the unknown.
#
# Saving data to JSON file: quest_data_20231228233728.json
# Data successfully saved to quest_data_20231228233728.json

# %%
def get_quest(player_race, player_class, race_lore, class_lore, model="gpt-4", word_limit=100):
    # Constructing the player profile
    player_profile = f"The player is a {player_race} {player_class}, known as an adventurer or traveler."

    # Assuming lore content is defined in lore_optimized import
# Example content for demonstration
enchanter_lore = "Lore about enchanters..."
dark_myr_lore = "Lore about Dark Myr..."


    
    # NPC description (Cleo)
    npc_description = """
    Cleo is a captivating, elf-like enchantress, an attractive figure dwelling in the seclusion of Halnir's Cave. 
    Her ethereal beauty, marked by distinctive pink furry ears and freckles, suggest a Fey or fairy heritage. 
    Cleo skillfully intertwines intelligence and charm, using her quick wit and innocent appearance to masterfully conceal her clandestine plots. 
    Though her playful and flirty demeanor may suggest innocence, beneath her exterior lies a shrewd, calculating mind not averse to using her blades when necessary. 
    Well-educated in elven traditions and street-smart like a rogue, Cleo navigates treacherous paths with ease and resourcefulness. 
    She manipulates situations to her advantage and is known for her unexpected appearances, each arrival a blend of danger and intrigue. 
    Despite being a reluctant quest giver, she flatters her victims into her complex machinations, always plotting with acute precision.
    """

    # Context for the NPC interaction
    context = f"Cleo {npc_description} the adventurer stumbles upon Cleo in a secret cavern in Halnir's cave. Cleo is there studing some old tomes about {castigue}.

    # Cleo's dialogue
    cleo_dialogue = f""" Cleo offers a quest, in 2nd person dialog. She seeks legendary cipher scrolls that are said contain the secrets to translating the language of Drak’Elri, 
    the language of dragons. Cleo use the lore of {race_lore} and the skills of {class_lore} to connive them to search the depths of Hainir's cave and beyond for these scrolls. 
    Cleo playfully teases the adventure in these matters. leveraging the adventures {player_race} {player_class}, especially about {race_lore} and {class_lore}, trying to coax them into this quest"""

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": cleo_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message["content"]


# Example variable content (ensure these are defined in your lore_optimized import)
# enchanter = "Lore about enchanters..."
# dark_myr = "Lore about Dark Myr..."

# Iterate through each combination of race and class
for race in races:
    for class_ in classes:
        race_lore = eval(race)  # Assumes 'dark_myr' variable contains the lore for Dark Myr
        class_lore = eval(class_)  # Assumes 'enchanter' variable contains the lore for Enchanters
        response = get_quest(race, class_, race_lore, class_lore)
        # ...

# %%
# Cleo's quest for tomes containing information on the Dragon Scrolls.
# Interates class and race combos


def get_quest(player_race, player_class, model="gpt-4", word_limit=100):
    # Constructing the player profile
    player_profile = f"The player is a {player_race} {player_class} known as an adventurer or traveler when engaging in dialog in 2nd person perspective."
    
    # NPC description (Cleo)
    npc_description = """
    Cleo is a captivating, elf-like enchantress, an attractive figure dwelling in the seclusion of Halnir's Cave. 
    Her ethereal beauty, marked by distinctive pink furry ears and freckles, suggest a Fey or fairy heritage. 
    Cleo skillfully intertwines intelligence and charm, using her quick wit and innocent appearance to masterfully conceal her clandestine plots. 
    Though her playful and flirty demeanor may suggest innocence, beneath her exterior lies a shrewd, calculating mind not averse to using her blades when necessary. 
    Well-educated in elven traditions and street-smart like a rogue, Cleo navigates treacherous paths with ease and resourcefulness. 
    She manipulates situations to her advantage and is known for her unexpected appearances, each arrival a blend of danger and intrigue. 
    Despite being a reluctant quest giver, she flatters her victims into her complex machinations, always plotting with acute precision.
    """
    
    # Context for the NPC interaction
    context = f"Cleo {npc_description} briefly speaks of the legend of the Dragon Accords contained in {castigue}. Cleo must wittingly pokes fun at the {player_profile} and their clueless nature in these matters. Calling player by non-gender specific pet names."
    
    cleo_dialogue = F"Cleo offers a quest to some rare tomes scaddered in the depths of Halnir cave. The tomes quite possibly contain cyphers capable of reading the language of Drak’Elrin {castigue}.  Cleo tries to persuade the player to help her."

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": cleo_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.9
    )
    return response.choices[0].message["content"]

def save_to_json(data, filename="quest_data.json"):
    print("Saving data to JSON file...")
    try:
        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to JSON: {e}")

# Lists of races and classes
races = ["dark_myr"]
classes = ["enchanter", "summoner", "rogue", "wizard" ]  # Add more classes as needed

# Dictionary to store all responses
quest_responses = {}

# Iterate through each combination of race and class
for race in races:
    for class_ in classes:
        response = get_quest(race, class_)
        quest_key = f"{race}_{class_}"  # Create a unique key for each combination
        quest_responses[quest_key] = response
        print(f"Race: {race}, Class: {class_}\n{response}\n")

# Save all responses to a JSON file
save_to_json(quest_responses)

# %%
# Cleo's quest for tomes containing information on the Dragon Scrolls.
# Interates class and race combos


def get_quest(player_race, player_class, model="gpt-4", word_limit=100):
    # Constructing the player profile
    player_profile = f"The player is a {player_race} {player_class} known as an adventurer or traveler when engaging in dialog in 2nd person perspective."
    
    # NPC description (Cleo)
    npc_description = """
    Cleo is a captivating, elf-like enchantress, an attractive figure dwelling in the seclusion of Halnir's Cave. 
    Her ethereal beauty, marked by distinctive pink furry ears and freckles, suggest a Fey or fairy heritage. 
    Cleo skillfully intertwines intelligence and charm, using her quick wit and innocent appearance to masterfully conceal her clandestine plots. 
    Though her playful and flirty demeanor may suggest innocence, beneath her exterior lies a shrewd, calculating mind not averse to using her blades when necessary. 
    Well-educated in elven traditions and street-smart like a rogue, Cleo navigates treacherous paths with ease and resourcefulness. 
    She manipulates situations to her advantage and is known for her unexpected appearances, each arrival a blend of danger and intrigue. 
    Despite being a reluctant quest giver, she flatters her victims into her complex machinations, always plotting with acute precision.
    """
    
    # Context for the NPC interaction
    context = f"Cleo {npc_description} briefly speaks of the legend of the Dragon Accords contained in {castigue}. Cleo must wittingly pokes fun at the {player_profile} and their clueless nature in these matters. Calling player by non-gender specific pet names."
    
    cleo_dialogue = F"Cleo offers a quest to some rare tomes scaddered in the depths of Halnir cave. The tomes quite possibly contain cyphers capable of reading the language of Drak’Elrin {castigue}.  Cleo tries to persuade the player to help her."

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": cleo_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message["content"]

def save_to_json(data, filename):
    print(f"Saving data to JSON file: {filename}")
    try:
        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to JSON: {e}")

# Lists of races and classes
races = ["dark_myr"]
classes = ["enchanter"]  # Add more classes as needed

# Dictionary to store all responses
quest_responses = {}

# Iterate through each combination of race and class
for race in races:
    for class_ in classes:
        response = get_quest(race, class_)
        quest_key = f"{race}_{class_}"  # Create a unique key for each combination
        quest_responses[quest_key] = response
        print(f"Race: {race}, Class: {class_}\n{response}\n")

# Generate a unique filename with timestamp
timestamp = datetime.datetime.now().strftime("%Y%m%d%H%M%S")
filename = f"quest_data_{timestamp}.json"

# Save all responses to a uniquely named JSON file
save_to_json(quest_responses, filename)

# %%
# Cleo's quest for tomes containing information on the Dragon Scrolls.
# Interates class and race combos


def get_quest(player_race, player_class, model="gpt-4", word_limit=100):
    # Constructing the player profile
    player_profile = f"The player is a {player_race} {player_class} known as an adventurer or traveler when engaging in dialog in 2nd person perspective."
    
    # NPC description (Cleo)
    npc_description = """
    Cleo is a captivating, elf-like enchantress, an attractive figure dwelling in the seclusion of Halnir's Cave. 
    Her ethereal beauty, marked by distinctive pink furry ears and freckles, suggest a Fey or fairy heritage. 
    Cleo skillfully intertwines intelligence and charm, using her quick wit and innocent appearance to masterfully conceal her clandestine plots. 
    Though her playful and flirty demeanor may suggest innocence, beneath her exterior lies a shrewd, calculating mind not averse to using her blades when necessary. 
    Well-educated in elven traditions and street-smart like a rogue, Cleo navigates treacherous paths with ease and resourcefulness. 
    She manipulates situations to her advantage and is known for her unexpected appearances, each arrival a blend of danger and intrigue. 
    Despite being a reluctant quest giver, she flatters her victims into her complex machinations, always plotting with acute precision.
    """
    
    # Context for the NPC interaction
    context = f"Cleo {npc_description} briefly speaks of the legend of the Dragon Accords contained in {castigue}. Cleo wittingly pokes fun the {player_profile} and their clueless nature in these matters. Calling player by non-gender specific pet names."
    
    cleo_dialogue = F"Cleo offers a quest to some rare tomes scaddered in the depths of Halnir cave. The tomes quite possibly contain cyphers capable of reading the language of Drak’Elrin {castigue}.  Cleo tries to persuade the player to help her."

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": cleo_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.9
    )
    return response.choices[0].message["content"]

def save_to_json(data, filename="quest_data.json"):
    print("Saving data to JSON file...")
    try:
        with open(filename, "w") as file:
            json.dump(data, file, indent=4)
        print(f"Data successfully saved to {filename}")
    except Exception as e:
        print(f"Error saving to JSON: {e}")

# Lists of races and classes
races = ["gnome"]
classes = ["enchanter", "summoner", "rogue", "wizard" ]  # Add more classes as needed

# Iterate through each combination of race and class
for race in races:
    for class_ in classes:
        response = get_quest(race, class_)
        print(f"Race: {race}, Class: {class_}\n{response}\n")
# Out:
# Race: gnome, Class: enchanter
# With an impish grin, Cleo teases the gnome enchanter, fluttering her pink furry ears in amusement, "Well, hello there, sweetling! I can see you're a lover of adventure and mystic arts!" Her eyes shine with mirth as she leans in closer, her voice dropping to a conspiratorial whisper, "How do you feel about a little treasure hunt? Nothing perilous, I promise..."
#
# She proceeds to tell the player about the valuable tomes scattered within the depths of Halnir cave, rumored to contain cyphers capable of deciphering the elusive dragon language, Drak’Elrin - knowledge that could unlock the secrets of the ancient Dragon Accord.
#
# Cleo continues her enticing proposal, her charm and cunning fully on display. "If you manage to sought out these tomes and bring them back, I assure you it will be worth your while. Are you game, darling?" Despite her playful tone, the serious gleam in her eyes suggests that this adventure could be more than it initially appears.
#
# Race: gnome, Class: summoner
# "Oh, sweet little summoner," Cleo begins, her voice soft and melodious, a clear sign she's about to dive into one of her plots. Her twinkling eyes lock on to the gnome, an innocent smile playing on her lips. "You know, I've been pondering over a certain predicament, and I think your skillset might just be the solution."
#
# She moves to a table, her fingers delicately tracing over a dusty and ancient-looking document illuminated by the dim glow of a nearby candle. It's clear this isn't some random parchment; it holds importance.
#
# "This," she starts, her voice dropping to a whisper as if unveiling a secret, "is a piece of the Dragon Accord. A document so old it predates most known races. It's filled with tales, legends... secrets. Yet, I hit a wall - the language of Drak’Elrin. A language as enigmatic as it is ancient."
#
# She turns to look back at the gnome, her eyes filled with a combination of excitement and pleading. "Imagine, dear gnome, the treasure trove of knowledge we could uncover, the mysteries we could solve... if only we could decipher it. We could leave our mark in history, a legacy that'll carry forward for ages. What do you say, will you help this poor damsel?"
#
# Cleo's voice held a playful lilt as she spoke, her enticing offer hanging in the air between them. Despite her elf-like charm and jocular tone, it was clear - this was no mere jest.
#
# Race: gnome, Class: rogue
# "Well, hello there, squirt," Cleo's voice drips with honey-sweet tones as she greets the gnome rogue. Her pink furry ears twitching with amusement, eyes twinkling with mischief. "I've got a bit of a task that needs someone... well, resourceful and brave, much like you. What say you, adventurer?"
#
# Her pale fingers trace the outline of the ancient tomes laid out on the rough wooden table in front of her. The dragon emblems etched onto their covers seem to shimmer in the dim cave light, hinting at secrets locked within their pages, waiting to be discovered.
#
# "There are more of these precious books scattered deep within Halnir’s cave," her voice drops to a hushed whisper, a playful smirk pulling at the corners of her mouth. "Imagine the treasures they could hold, not to mention the knowledge about the Dragons and their elusive language, Drak'Elrin."
#
# Her gaze falls back on the gnome, her eyes inviting and challenging all at once. "Are you up for some exploration, darling?"
#
# Race: gnome, Class: wizard
# "Cleo catches sight of the gnome wizard across the cave, her pink ears perking up with interest. ""Well, well, if it isn't the little wanderer,"" she calls out, beckoning you over with a flirty smirk playing on her lips. ""Been poking your nose into curious corners, haven't you, darling?"
#
# She leans in, lowering her voice to a conspiratory whisper, her eyes glinting with mischief and intrigue. "Care to embark on a little...exploration, dear wanderer? I have a quest for you, you know, if you are up for the challenge."
#
# Cleo draws a folded parchment from her pocket, offering it to you. The parchment crisply unfolds revealing an intricate map of Halnir's Cave, spots marked with what seems like coded messages. "These are the locations of some very rare tomes, they hold secrets that could change our understanding of the world. But the catch is..." she pauses, her captivating eyes locking onto you, "...they are written in Drak’Elrin, the ancient language of dragons."
#
# She leans back, crossing her arms under her chest. "I know, darling. It's a huge ask. But, if anyone can, it's you. An adventurer. A traveler. A gnome wizard. What do you say, love? Will you help this humble elf?""

# %% [raw]
# Race: gnome, Class: enchanter
# "Well, hello there, sugarplum," Cleo begins, her pink ears perking up at the sight of the gnome enchanter. Her eyes twinkle with mischief as she looks the adventurer up and down. "I see you're not one to shy away from a challenge," she says playfully, waving a hand toward the depths of Halnir Cave.
#
# "The thing is, I've got a bit of a problem on my hands. You see, there are some precious tomes scattered deep within this cave. They're no ordinary books; they quite possibly contain cyphers capable of reading the ancient dragon language, Drak’Elrin."
#
# Her eyes sparkle with a cunning glint as she continues, "I would fetch them myself, of course, but these old bones aren't as spry as they used to be." She chuckles, adding, "Besides, I'm sure a daring adventurer such as yourself would find the task far more... exhilarating."
#
# Cleo's voice softens as she explains the importance of obtaining these tomes. She speaks of the Dragon Accord, the ancient document written in Drak’Elrin, its mysteries yet to be unlocked. She recounts the struggles of Narian and Kaolyen, their pursuit of understanding the Dragon Accord, and the conflicts that hinder their progress.
#
# "So, sweetling," Cleo finally says, fixing the gnome enchanter with a captivating gaze, "Are you ready to delve into the heart of the unknown, retrieve those tomes, and help unlock the secrets of an ancient language?"
#
# With a suggestive wink, she adds, "Who knows, maybe this adventure will lead to an exciting story for you to tell your grandkids one day...assuming, of course, you survive."
#
# Race: gnome, Class: summoner
# With her eyebrows raised in a playful challenge, Cleo grins, "Well, aren't you a curiosity, sprout? I heard stories of gnome summoners wandering about, but I must say you're my first up-close encounter. I hope you're not as clueless as you appear!" She winked, her pink, furry ears twitching with amusement.
#
# Sighing dramatically, she leaned back against the wall of the cave, her eyes glinting with hidden plots. "Now, I've got this little problem, you see," she began, spinning her dagger nonchalantly. "It involves some ancient tomes scattered about in the depths of this old cave. Quite dusty, I imagine, and not the kind of thing a dainty gnome would usually bother with."
#
# "But," she continued, her voice dropping to a conspiratorial whisper, "these aren't just any tomes. They're rumored to contain the key to deciphering an ancient dragon language. Quite the valuable find for any inquisitive mind." She paused, her gaze meeting yours, full of anticipation, "So, what do you say, darling? Fancy a little adventure?"
#
# Race: gnome, Class: rogue
# Cleo's piercing green eyes meet yours, a smirk playing on her lips as she dangles the quest in front of you like a carrot. She leans in, her voice dropping to a whisper, "Now sugarplum, I've got a little job that needs doing. Only for the brave and clever though, and I can't help but think you fit the bill."
#
# She tosses her mane of curly hair over her shoulder, her gaze steady. You notice the subtle shift in her demeanor, the playful tone replaced with a serious one. "It's no small task," she continues, "The tomes you need to find are scattered in the treacherous depths of Halnir Cave."
#
# "But," she winks at you, "I have a feeling you're up for the challenge. Besides, there'll be a pretty reward waiting for you. How about it, darling?"
#
# Race: gnome, Class: wizard
# "Oh, my brave little adventurer, I knew I could count on you," Cleo says, a mischievous spark gleaming in her almond-shaped eyes. "The challenge might be great, but I trust in your capabilities. It's not easy, knowing something as marvelous as the Dragon Accord is just out of our reach. But with your magic and my charm, there's nothing we can't conquer together."
#
# She leans in, her face just inches from the player's, her pink, furry ears standing on end. "Listen closely, dearest. Deep within Halnir Cave lies a collection of tomes. These aren't your ordinary dusty old books. Oh no, they're said to contain the keys to the very language of Drak’Elrin. Imagine that! I'd go myself, darlin', but you know how dreadful I am with riddles and that dragon tongue is nothing but riddles."
#
# "Bring me those tomes and I will make sure you're rewarded lavishly." She winks at the gnome wizard, leaving the nature of the reward to the player's imagination.
#
# "Remember, dearest, the cave is full of danger, but remember you're not only a traveler, you're an adventurer. I believe in you." Her voice fades as she turns away, her white, fluffy tail swishing hypnotically behind her, leaving the player with a precarious choice and a beating heart.

# %% [raw]
# Race: ogre, Class: dire_lord
# Cleo tilts her head slightly, her pink furry ears visible under her hair. Her eyes sparkle with mischief as she examines the towering figure before her. "An Ogre Dire Lord, huh?" she muses, her voice laced with amazement and a hint of amusement. "You're not at all what I expected when I heard an adventurer was coming. I thought maybe a nimble rogue or a wise wizard, but an Ogre... now that's interesting!"
#
# She gives the Dire Lord an appraising look, her gaze lingering on his massive form, clearly built for strength and endurance. "But, I suppose it's good to have someone with your... physical prowess around."
#
# Cleo then leans closer to the Dire Lord, her eyes twinkling with a playful glint. "Tell me, big guy, how much do you know about the Terminus history? The Dragon Accords?" she asks, her tone teasing.
#
# When the Ogre Dire Lord grunts, a clear indication of his lack of knowledge in these matters, Cleo bursts into a peal of silvery laughter. "Oh, I thought as much!" she exclaims, wiping a tear from her eye.
#
# "But worry not, dear adventurer," Cleo continues, regaining her composure. "I have a task that could help fill those gaps in your understanding. I need you to retrieve some tomes from the nearby caves. They hold a wealth of information about the world we live in, the Dragon Accords, and much more. Think you can handle that?"
#
# With a challenging smile, Cleo awaits the Ogre's response, her eyes filled with anticipation.
#
# Race: ogre, Class: shaman
# Cleo, with a mischievous twinkle in her eyes and an impish grin, looks at the Ogre Shaman before her. "Ah, an adventurer," she purrs, her voice a low, enchanting melody. "I see, someone who fancies mysteries and ancient tales. Perfect."
#
# She tilts her head slightly, examining the ogre shaman with a flicker of amusement dancing in her eyes. "Ogre shamans, yes, you are revered for your strength and connection with the spirits, but are you as knowledgeable about the intricacies of Terminus history as you are in your shamanic arts?"
#
# She chuckles softly, her eyes sparkling with playful teasing. "No offense, dear, but the complexities and subtleties of history and lore might be a bit out of your...how shall I say this... realm?"
#
# With a flick of her wrist, she conjures an image of ancient tomes in the air between them. "I have a task for you, if you're up for it. There are some ancient tomes, relics of the past, hidden in nearby caves. Their knowledge could prove invaluable in these uncertain times."
#
# Her eyes, now serious, bore into the ogre's. "Can you retrieve them, mighty shaman? Or should I look for a more... scholarly type?" Her tone is a mix of challenge and intrigue, the gauntlet thrown. The elf-like enchantress awaits the ogre's response, a coy smile playing on her lips.
#
# Race: gnome, Class: enchanter
# Cleo gives you a playful smile, her pink, furry ears flicking with amusement.
#
# "Hail, traveler!" she greets, her voice melodious and warm.
#
# "I've heard tales of your exploits. A gnome enchanter, aren't you? Quite an uncommon path you've chosen. I wonder, do you have the same thirst for knowledge as I do?"
#
# She tilts her head, her gaze assessing you with a hint of mischief. "I seek tomes of great significance, hidden in the nearby caves. Their knowledge could help unravel the mysteries of Terminus and beyond. I can't fetch them myself... it's a bit complicated."
#
# Cleo leans in closer, her eyes sparkling with intrigue. "What do you say, adventurer? Would you lend your aid to a humble elf-like enchantress?" Her words, while playful, carry an undercurrent of urgency, emphasizing the gravity of her request.
#
# Race: gnome, Class: summoner
# Cleo's pink ears twitch with a mix of curiosity and amusement as she studies the gnome summoner standing before her. Her voice, melodic and laced with a hint of mischief, echoes through the cave. "Ah, a traveler of sorts, aren't you? An adventurer who summons creatures from the ether to do his bidding. How fascinating."
#
# She twirls a lock of hair between her fingers, her eyes twinkling with concealed excitement. "I see you have a thirst for knowledge, a desire for discovery. And I might just have the perfect task for you."
#
# She leans in closer, her voice dropping to a conspiratorial whisper. "There are tomes of great value hidden in caves nearby. Ancient texts that hold secrets about the world of Terminus, its history and the formidable creatures known as Dragons. These tomes could prove invaluable in your quest for understanding."
#
# She pulls back, her eyes scanning the gnome summoner, assessing his reaction. "Will you assist me in retrieving these tomes? It won't be easy, but I have a feeling you are not one to shy away from a challenge."

# %%
def get_completion(prompt, model="gpt-4"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7,
    )
    return response.choices[0].message["content"]

# Assuming 'context', 'player_profile', and 'cleo_dialogue' are defined earlier in your code.
# Example:
context = "create a sysnopsis of content maintain the style and tone of the original author."
# player_profile = "..."
cleo_dialogue = f"give a summary of {on_keeping}."

# Combining messages
messages = [
    {"role": "system", "content": context},
    # {"role": "user", "content": player_profile},
    {"role": "assistant", "content": cleo_dialogue}
]

# API Call
response = openai.ChatCompletion.create(
    model="gpt-4",
    messages=messages,
    temperature=0.7
)

print(response.choices[0].message["content"])
# Out:
# "The Keeping of Things" is a reflective and humble account of a man who has dedicated his life to preserving the history of Terminus and beyond. He doesn't regard himself as a person of importance, despite having been accused of various offenses and being offered bribes to skew his records. The author's dislike for dishonesty is clear, as he chastises a former friend for selling fabricated stories for profit. Despite the hardships he's endured, such as his property being destroyed and his life threatened, he continues his work. The man identifies himself as "The Keeper," someone who safeguards knowledge and history. He hopes that after he's gone, there will be someone who shares his passion to take up his role, a role he perceives as critical to the world. His tone throughout is sincere, modest, and filled with a steadfast dedication to his mission.

# %%
castigue = """
"The Keeping of Things" is a reflective and humble account of a man who has dedicated his life to preserving the history of Terminus and beyond. He doesn't regard himself as a person of importance, despite having been accused of various offenses and being offered bribes to skew his records. The author's dislike for dishonesty is clear, as he chastises a former friend for selling fabricated stories for profit. Despite the hardships he's endured, such as his property being destroyed and his life threatened, he continues his work. The man identifies himself as "The Keeper," someone who safeguards knowledge and history. He hopes that after he's gone, there will be someone who shares his passion to take up his role, a role he perceives as critical to the world. His tone throughout is sincere, modest, and filled with a steadfast dedication to his mission.

"The Keepings of Castigue" is an intriguing collection of letters that delve into the mysterious world of Terminus, its history, and the formidable creatures known as Dragons. The author connects deeply with these letters due to their rarity and invaluable insights. The correspondence between Castigue and Kaolyen Greyborne provides a glimpse into their friendship and their shared pursuit of understanding the Dragon Accord. 
The first letter from Narian to Kaolyen reveals their struggles in deciphering the Dragon Accord, a document predating even the oldest known races. They received initial help from the Dwarves of Khadassa, but that connection was severed, possibly due to growing conflicts. The Myr and tribes of Ginto were other potential sources of aid, but those avenues appeared equally challenging. 
Narian's departure to the Dwarven realm of Khadassa is fraught with uncertainty and danger, but he undertakes it in the hope of unlocking the mysteries of the Dragon tongue. He entrusts the task to Kaolyen, should he fail. These letters, filled with camaraderie, fear, and awe, offer a fascinating look into a time in Terminus' history that is often overlooked.


In a letter to Narian, Kaolyen Greyborne expresses his fascination and struggles with the arduous task of deciphering the Dragon Accord, a document written in the enigmatic and heavily enchanted language of Drak’Elrin. Although initial efforts to translate the Accord proved challenging due to the document's magical safeguards, Kaolyen discovers that even mere copies of the document are protected by the same powerful enchantments, which prevent its destruction or alteration.
Kaolyen's experiments with the document reveal its extraordinary resilience to fire, water, and other harmful substances, and its ability to deflect arrows. However, he also observes that these protective enchantments fade over time, causing the document's inscriptions to disappear. 
Despite his deep intrigue and relentless efforts, Kaolyen concedes that the task of deciphering the Dragon Accord may be impossible for anyone who is not a Dragon. He urges Narian to consider this reality, while also hinting at impending conflicts that may require their attention. 
The letter is a testament to Kaolyen's perseverance and resourcefulness, but also a sobering reminder of the limitations of their understanding and the looming threats they face.

Narian Castigue, a historian from Havensong, pens a letter to his friend Kaolyen Greyborne, detailing his perilous journey to seek the counsel of the Snow Dragon, Tel’Nharssis. Guided by Dwarf King Khazas and Archai warrior Rel-Cirin, he traverses the treacherous Tenebrous Tundra to a hidden cave. There, he confronts the Dragon, seeking to understand the ancient dragon language, Drak’Elrin, inscribed on a document they have dubbed 'The Dragon Accord'. The Dragon, enraged by the perceived audacity of their request, threatens to raise alarm amongst his kin, potentially leading to war. As they retreat, they encounter dead bodies and a menacing figure known as the Ill Watcher, hinting at imminent conflict. Though the journey does not yield the desired knowledge, Narian remains committed to their quest.
"""

# %%
def get_master_shanyu_quest(player_race, player_class, model="gpt-4", word_limit=100):
    
    context = f"In the world of Terminus during the {frail_age}, within the foothills of the moutains to the west of Avendyr's Pass , lies a small village where Master Shanyu resides. He was born in the {frail_age} and has a deep understanding 
    

    player_profile = f"The player is a {player_race} {player_class} and is known as an adventurer. This character has their own unique strengths, weaknesses, and spiritual journey. 
    # master_shanyu_dialogue = f"""
    # Master Shanyu greets the player warmely, knowing there place in the {frail_age} and peers into their soul. He says: 'Ah, adventure. Your journey up the mountain will be reflective of the journey within your soul. Let me tell you what your ascent symbolizes...'
    # """
    
    # master_shanyu_dialogue = f"""
    # Master Shanyu greets you warmly, his gaze seeming to transcend time. 'Ah, adventurer, descendant of a lineage both ancient and strong,' he begins. 'In you, the echoes of your ancestors resonate, carrying the wisdom and strengths of ages past. As you embark on your journey up this sacred mountain, remember that you tread a path walked by those who came before you. This journey is a reflection of your soul's quest, a journey interwoven with the legacy of your ancestry. Let the mountain reveal not only its secrets but also the hidden tales of your lineage. Your ascent here is more than a climb; it is an awakening of your heritage and inner self. Let me guide you in understanding what this ascent truly symbolizes...'
    # """
    
    master_shanyu_dialogue = f"""
    Master Shanyu greets you warmly, his eyes reflecting a depth of ancient wisdom. 'Welcome, adventurer, descendant of a lineage both ancient and strong,' he begins. 'Within you, the echoes of your ancestors {frail_age} stir, whispering secrets carried through the ages. Your first step on this sacred mountain is not merely a physical ascent, but a journey deep into the heart of your heritage. The path you seek is one your forebears have tread, hidden yet waiting for one who can truly see. Seek the entrance to a secret cave, shrouded in mystery and time. This cave holds more than just echoes of the past; it is a gateway to understanding the bond between your soul's quest and the legacy of those who came before you. Let the whispers of the mountain guide you to this hidden sanctum, where the first chapter of your ascent – and your awakening – begins.'
    """

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": master_shanyu_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].message["content"]

# Lists of races and classes
races = ["scar"]
classes = ["warrior", "monk", "rogue"] # "ranger", "cleric", "druid", "wizard", "enchanter", "paladin", "shaman", "summoner"]

# Iterate through each combination of race and class
for race in races:
    for class_ in classes:
        response = get_master_shanyu_quest(race, class_)
        print(f"Race: {race}, Class: {class_}\n{response}\n")

# %%
# Adjusting the "Temperature = .9" the stories will vary greatly.
# insert reference material here and assign a varible "subject = """ text """

# Genre and writing style.
fantasy_subgenres = "Mythic Fantasy"
author_styles = "Epic and World-Building"

# Narration POV



# AI Character knowledge, motivations and knowledge of key plot elements


# Setting

# Prompt
prompt = f"""

The current age is{frail_age} based on the history of the {age_of_chaos}, Being accurate to the history of the ages, give the name and history on an old {monk} {archai} master. Who sought mastery of himself "the Way" and all that is in a mysterious mountain cave where a past master scribed his wisdom and teachings before ascending higher up and through the mountain.  leaving a trail of mystery as legends have it he meditated for 100 years. legends speak of ascending the mountain before transforming himself into conscious crystal structure that is linked to fracture hidden in the moutain. 

"""

# Get response from user
response = get_completion(prompt)

# Print response
print(response)

# %%
# Adjusting the "Temperature = .9" the stories will vary greatly.
# insert reference material here and assign a varible "subject = """ text """

# Genre and writing style.
fantasy_subgenres = "Mythic Fantasy"
author_styles = "Epic and World-Building"

# Narration POV



# AI Character knowledge, motivations and knowledge of key plot elements


# Setting

# Prompt
prompt = f"Summarize {castigue_3} into a simple summary."

# Get response from user
response = get_completion(prompt)

# Print response
print(response)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_29704\1909315021.py in <module>
#      16
#      17 # Prompt
# ---> 18 prompt = f"Summarize {castigue_3} into a simple summary."
#      19
#      20 # Get response from user
#
# NameError: name 'castigue_3' is not defined

# %% [raw]
# "The Keepings of Castigue" are a series of letters exchanged between Narian Castigue and Kaolyen Greyborne, two scholars trying to translate a document known as "The Dragon Accord". The letters provide an insight into Terminus' history, a time that is under-documented. The Dragon Accord predates the arrival of Kaolyen's race and was initially translated with the help of the Dwarves of Khadassa. However, their aid was cut off due to a possible conflict. The scholars also hoped to gain insight from the tribes of Ginto, but they are reclusive and focused on realms farther east.
#
# The letters reveal that the Dragon Accord is written in Drak’Elrin, a language of the Dragon King himself, heavily fortified with enchantment. The scholars face challenges in the form of protective magic that causes copies of the document to become heavy, resistant to flames and water, and makes ink vanish. Despite these obstacles, they persist in their research. The letters end with Kaolyen deciding to visit the Remnant and relocate closer to his city due to rumors of conflicts threatening every region, race, and realm. He acknowledges that their pursuit of understanding the Dragon Accord is coming to a close, not due to a lack of effort, but because they are not Dragons.

# %% [raw]
# forth attempt,
# The name of this master is Xao Ling, a revered figure in the annals of Terminus history. Xao Ling was born as a humble Archai, his body infused with the resilient minerals of the Su’Roa mountains. From an early age, he demonstrated an innate understanding of the energies that coursed through his body, and a fierce dedication to mastering the harmony between his physical and spiritual selves.
#
# As Xao was growing up, he heard tales of an ancient master who had lived in isolation in a mysterious mountain cave. This master, known only as the Ascendant, had spent his life in pursuit of ultimate enlightenment, referred to as "the Way". The Ascendant had left behind his teachings etched into the walls of the cave before disappearing into the higher reaches of the mountain.
#
# Driven by an insatiable curiosity and a burning desire to follow the Way, Xao Ling decided to seek out the cave of the Ascendant. After a grueling journey, he found the cave and set about studying the wisdom etched into its stone walls. He meditated on the teachings, tested his body’s limits, and honed his mind to razor sharpness.
#
# Legends say that Xao Ling meditated in the cave for a hundred years, his body sustained by the elemental energy fused within him. During this time, he mastered his body and spirit to such an extent that he was able to perform miraculous feats of strength, agility, and endurance.
#
# Finally, it is said that Xao Ling achieved the ultimate enlightenment he had been seeking. He ascended the mountain, leaving behind a trail of crystalline footprints. At the mountain's peak, he transformed himself into a conscious crystal structure, forever linked to the fracture hidden within the mountain.
#
# Today, Xao Ling is revered as a paragon of discipline, harmony, and enlightenment. His tale continues to inspire all those who walk the Way, and his crystalline form serves as a beacon of hope and strength for the Archai people.

# %% [raw]
# third attempt
#
# This legendary master was known as Kyru the Ascendant, a renowned Archai Monk from the realm of Su'Roa. Known not only for his tremendous physical strength but also for his spiritual prowess, Kyru was an exemplar of the Monk's way of life, demonstrating the power that comes from harmony between the body and the soul.
#
# Kyru's journey towards mastery began with a vision during an intense meditation session. He saw a mysterious mountain cave, a place of profound power and wisdom. The vision was so vivid, so compelling, that Kyru knew he had to find this cave. He left his home in Su'Roa and embarked on a long and arduous journey, driven by his unshakeable belief in the vision.
#
# After years of wandering, Kyru finally found the mountain and the cave that he had seen in his vision. Inside, he discovered ancient writings left by an unknown master, detailing profound teachings about the nature of the self and the universe. These teachings, which came to be known as "the Way," resonated deeply with Kyru, and he spent many years studying them, meditating, and training in the cave.
#
# As Kyru delved deeper into the teachings and practiced the disciplines outlined within, he began to notice changes within himself. His physical and spiritual powers grew, and he found himself able to perform feats that he had once thought impossible. His body and spirit became more and more attuned to the elemental energy of the world around him, and he felt a deep connection to the fracture in the world located near the mountain.
#
# As the legends say, Kyru meditated in the cave for a hundred years. During this time, his body gradually transformed into a powerful crystal, a physical manifestation of his spiritual ascendance. This crystal, it is said, is still linked to the fracture near the mountain, acting as a conduit for the raw, elemental energy of the universe.
#
# Kyru's story has since become a part of Archai folklore, a testament to the power of discipline, spiritual growth, and self-mastery. His teachings, preserved within the mountain cave, continue to inspire and guide those who seek to walk the path of the Monk.

# %% [raw]
# Based on both ages
# Master Tenzin, the Enlightened Ascendant, was a revered figure in the annals of Monk history. His tale begins in the humble village of Khye-Shan, where he was born to a family of laborers. Despite the hardships of his early life, young Tenzin was drawn to the monastic traditions of his ancestors, and sought solace in the pursuit of spiritual enlightenment.
#
# In the prime of his youth, Tenzin left his village and ventured into the treacherous peaks of the Shang-La mountains. Here, he discovered the hidden cave of Master Zhang, an ancient monk whose teachings were etched into the very walls of the cave. Master Zhang was said to have meditated for a century before transforming into a powerful crystal linked to a nearby fracture in the world.
#
# In the cave, Tenzin discovered the wisdom and teachings of Master Zhang. He spent decades in solitude, meditating under the watchful gaze of the crystal, absorbing the ancient teachings etched on the cave walls. It was a time of profound spiritual growth for Tenzin, and he mastered the art of channeling his chi, the vital energy within him, to perform feats of humanly impossible strength and agility.
#
# As Tenzin aged, his wisdom and mastery over his chi grew exponentially. He developed the ability to manipulate the elements around him, harnessing the wind to leap incredible heights, and drawing energy from the earth to bolster his strength. His body became a living weapon, capable of devastating feats that echoed the legends of Master Zhang.
#
# In his final years, Tenzin returned to his village of Khye-Shan, sharing his profound knowledge and teachings with the younger generation. He lived out his days as a revered elder, guiding the village with his wisdom. When he finally passed, legends say that his body dissolved into a cascade of shimmering energy, leaving behind a single crystal, much like the one he had found in Master Zhang's cave.
#
# To this day, villagers of Khye-Shan speak in hushed tones of the legendary Master Tenzin, the Enlightened Ascendant, a testament to the strength of the human spirit and the power of perseverance. His crystal remains in the village, an enduring symbol of the ancient monastic traditions and the path to enlightenment.

# %% [raw]
# Name: Master Eolande of the Crystal Ascension
#
# Master Eolande was one of the most revered and ancient monks of the Archai race. Born in the tumultuous times of the Deicide War, Eolande spent his early years as a warrior, using his body as a weapon against the Revenant threats. However, the carnage and destruction he witnessed during this time deeply impacted him, leading him to renounce his warrior ways and seek a path of inner peace and harmony.
#
# He retreated to the solitude of a cave nestled in the towering cliffs of Su'Roa where he spent his days in deep meditation, seeking to understand the true nature of existence. Over the years, his understanding of the world around him deepened, and he started to put his wisdom into writings. These writings later became the foundation of his teachings, known as the Crystal Ascension, a spiritual path that sought to harmonize the Archai with the elemental nature of their homeland.
#
# With time, Eolande's teachings gained followers who sought the tranquility and wisdom he offered. However, even as his following grew, Eolande continued to seek a deeper connection with the world around him. This quest led him to attempt a feat no Archai had dared before - to ascend into a higher form of existence.
#
# For a hundred years, it is said that Eolande meditated without interruption, his body sustained by his elemental connection to the world around him. As the years passed, his form started to transform, his body taking on the shimmering qualities of the precious minerals and crystals of Su'Roa. After a century of meditation, Eolande finally achieved his goal, his body transformed into a magnificent crystal of unparalleled beauty and power.
#
# This crystal, known as the Crystal of Eolande, is said to be linked to a nearby fracture in the world, a testament to the power of Eolande's ascension. Today, his teachings continue to guide the Archai monks, his wisdom echoing through the centuries, a beacon of hope and tranquility amidst the uncertainty of the Frail Age. The cave where Eolande achieved his ascension remains a sacred site for the Archai, a place of pilgrimage where they seek guidance and inspiration from the wisdom of their ancient master.

# %% [raw]
# Based on the frail age:
#
# Named Master Xian, he was revered as an unparalleled sage and warrior during the Age of Chaos. Born an Archai, he was enslaved by the dark Celestial Lord and, like his brethren, was forced to graft elements onto his being. However, Master Xian chose the rare and powerful element of crystal, and through its infusion, his arcane core gained a unique resonance that magnified his physical and spiritual prowess.
#
# Master Xian's life was one of discipline and hardship, but he found solace in the teachings of the ancient Monks. He embraced their philosophies and practices with unwavering dedication, transforming his body and soul into a holistic weapon of devastating power. His disciplined mind and his crystalline body made him a formidable adversary, and his spiritual strength, a beacon of hope and resilience for his enslaved kin.
#
# When the Archai finally rose against their oppressors, Master Xian was at the forefront, leading the charge with an unyielding spirit and a fierce determination. His mastery of the Monk's teachings allowed him to turn the tide of many battles, and his victory cries became a symbol of the Archai's fight for freedom.
#
# After their liberation, Master Xian retreated to a secluded cave nestled in the heart of Su'Roa. There, he began to transcribe his wisdom and teachings onto the cave walls, intending to guide future generations of Archai and Monks alike. His writings spoke of harmony between the body and the soul, discipline, sacrifice, and the

# %% [raw]
# Name: Master Elikar Windwhisper
#
# Master Elikar Windwhisper is an old, revered Monk rooted in the rich history of the Archai. Born on the crystalline planet of Roa, Elikar is one of the last living Archai who can recall the oppressive reign of Roa's dark Celestial Lord. His form is distinct, his arcane core having acclimated to the wind element during his True Birth ceremony. His body is adorned with open striations and markings that resemble flowing currents of air, giving him an ethereal and majestic appearance.
#
# Elikar was bred as a slave, like many Archai of his time. However, he was not one to yield to despair. He found solace in the ancient teachings of the Monks, honing his body and soul into a holistic weapon. His longstanding discipline and unwavering obedience to these teachings earned him the respect and admiration of his fellow slaves.
#
# When the time came for the Archai to rise against their oppressors, Elikar was at the forefront. His formidable martial abilities, coupled with his ability to inspire and rally his brethren, played a crucial role in the successful liberation of the Archai.
#
# After the liberation, Elikar chose not to rest on his laurels. Instead, he sought to build a culture of endurance, poise, and intrepidness within the Archai society on Terminus. He became a master in teaching the way of the Monk to the

# %%
import openai

def get_master_shanyu_quest(player_race, player_class, model="gpt-4"):
    context = """
    You are in the world of Terminus, high in the Roan Mountains. You've journeyed to a plateau where Master Shanyu, a wise Earth Monk, resides. Master Shanyu is known for his unique ability to see into the souls of adventurers, drawing parallels between their inner journey and their physical climb up the mountain, based on their race and class.
    """

    player_profile = f"You are a {player_race} {player_class}. As you approach Master Shanyu, you feel a sense of calm and introspection."

    master_shanyu_dialogue = f"""
    Master Shanyu looks at you with a gentle gaze and says: 'Ah, a {player_race} {player_class}. Your journey up the mountain will be a mirror to your soul's journey. Let me share with you what your ascent symbolizes...'
    """

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": master_shanyu_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7
    )
    return response.choices[0].essage["content"]

# Example player attributes
player_race = "Human"
player_class = "Warrior"

# Call the function
response = get_master_shanyu_quest(player_race, player_class)
print(response)

# %%
import openai

def get_master_shanyu_quest(player_race, player_class, model="gpt-4", word_limit=100):
    context = """
    You are in the world of Terminus, high in the Roan Mountains. You've journeyed to a plateau where Master Shanyu, a wise Earth Monk, resides. Master Shanyu is known for his unique ability to see into the souls of adventurers, drawing parallels between their inner journey and their physical climb up the mountain, based on their race and class.
    """

    player_profile = f"You are a {player_race} {player_class}. As you approach Master Shanyu, you feel a sense of calm and introspection."

    master_shanyu_dialogue = f"""
    Master Shanyu looks at you with a gentle gaze and says: 'Ah, a {player_race} {player_class}. Your journey up the mountain will be a mirror to your soul's journey. Let me share with you what your ascent symbolizes...'
    """

    # Combining messages
    messages = [
        {"role": "system", "content": context},
        {"role": "user", "content": player_profile},
        {"role": "assistant", "content": master_shanyu_dialogue}
    ]

    # API Call
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0.7
    )

    full_response = response.choices[0].message["content"]
    # Limiting the response to the word limit
    limited_response = ' '.join(full_response.split()[:word_limit])
    
    return limited_response

# Example player attributes
player_race = "Human"
player_class = "Warrior"

# Call the function
response = get_master_shanyu_quest(player_race, player_class)
print(response)

# %%
# Adjusted dialogue portion in the function
master_shanyu_dialogue = f"""
    Master Shanyu looks at you with a gentle gaze and says: 'Ah, a seeker of strength and discipline. Your journey up the mountain is a reflection of your own path. The climb – steep and challenging – mirrors the courage and resolve required in your pursuits. Let me share with you what your ascent symbolizes...'
    """

# The rest of the function remains the same
